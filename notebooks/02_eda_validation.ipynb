# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../dataset/loans.csv")

# %%
df = pd.read_csv("../dataset/loans.csv")
print(df.shape)
# Out:
# (1000, 10)

# %%
df.head()
# Out:
#    age  monthly_income  loan_amount  interest_rate  tenure_years  monthly_emi  \
# 0   59           82761      1286753           8.31            12      14148.0
# 1   49           61368      1025947          11.15             3      33661.0
# 2   35           31783       572900          14.51             2      27645.0
# 3   28           66914       761227           9.16            10       9709.0
# 4   41           95507      1647098          10.73            13      19621.0
#
#    dependents  credit_score employment_type stress_level
# 0           2           782        salaried          Low
# 1           2           819        salaried         High
# 2           2           691        business         High
# 3           0           787        salaried          Low
# 4           0           786        salaried          Low

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              1000 non-null   int64
#  1   monthly_income   1000 non-null   int64
#  2   loan_amount      1000 non-null   int64
#  3   interest_rate    1000 non-null   float64
#  4   tenure_years     1000 non-null   int64
#  5   monthly_emi      1000 non-null   float64
#  6   dependents       1000 non-null   int64
#  7   credit_score     1000 non-null   int64
#  8   employment_type  1000 non-null   object
#  9   stress_level     1000 non-null   object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 78.2+ KB
#                age  monthly_income   loan_amount  interest_rate  tenure_years  \
# count  1000.000000     1000.000000  1.000000e+03    1000.000000   1000.000000
# mean     40.445000    67849.668000  1.057371e+06      11.596850      8.191000
# ...

# %%
sns.countplot(data=df, x="stress_level")
plt.title("Stress Level Distribution")
plt.show()

# %%
sns.scatterplot(
    data=df,
    x="monthly_income",
    y="monthly_emi",
    hue="stress_level",
    alpha=0.6
)
plt.title("Income vs EMI by Stress Level")
plt.show()
